# %%
from healing_mnist import *

# %%
d = HealingMNIST(min_seq_len = 1, max_seq_len=5, square_count=3)
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# /home/cctrotte/krauthammer/melissa/healing_mnist/healing_mnist.py:117: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.train_images = np.array(train_images)
# ...

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(15, 8))
j = 1
index = random.choice(range(1, len(d.train_images)))
print(index)
for i, image in enumerate(d.train_images[index]):
    fig.add_subplot(j, 11, i + 1)
    plt.imshow(image)
# Out:
# 18228
